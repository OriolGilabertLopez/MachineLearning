# %% [markdown]
# # 1. OBJETIVO
#
# En este Notebook vamos a predecir...

# %% [markdown]
# # 2. IMPORTACIÓN DE DATOS
#
# El primer paso que debemos realizar es importar los datos, visualizarlos y tener una idea general de como son y como se distribuyen. Para ello, cargamos los datos al notebook y seguidamente leemos los paths con la libreria `import os`.

# %%
import os
os.path("/kaggle/input")

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
